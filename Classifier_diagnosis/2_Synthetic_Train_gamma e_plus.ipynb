# %%
# imports
import h5py
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as func
import torch.optim as optim
from matplotlib.colors import LogNorm
import yaml

# %%
with open('extra_block_cell_list.yaml', 'r') as f:
    extra_block = yaml.safe_load(f)['extra_block']

# %%
class DataProcessor():
    def __init__(self, particle_one, particle_two, shuffle=True, train_prop=0.7, valid_prop=0.3, test_prop=0.1):
        super(DataProcessor,self).__init__()
        self.CLASS_ONE = particle_one
        self.CLASS_TWO = particle_two
        self.c1 = h5py.File('/fast_scratch_1/QVAE/data/calo/'+self.CLASS_ONE+'.hdf5', 'r')
        self.c2 = h5py.File('/fast_scratch_1/QVAE/data/calo/'+self.CLASS_TWO+'.hdf5', 'r') 
        self.gen_one = 'gen_'+particle_one
        self.gen_two = 'gen_'+particle_two
        self.shuffle = shuffle
        self.train_prop = train_prop
        self.valid_prop = valid_prop
        self.test_prop = test_prop
        self._BASE = '/home/s4hoque/DwaveSampInteg'

        self.gen_piplus = '/home/blazerjia/saved_output/RBM/piplus/18-13-51/synthetic_images_piplus.pt'
        self.gen_gamma = '/home/blazerjia/saved_output/unified/synthetic_images_gamma.pt'
        self.gen_eplus = '/home/blazerjia/saved_output/unified/synthetic_images_eplus.pt'

        self.gen_dict = {
            'gen_piplus': self.gen_piplus,
            'gen_gamma': self.gen_gamma,
            'gen_eplus': self.gen_eplus
        }
        self.bool_mask_list = None
        
        
    def flattened_class_data(self, class_num):
        c_layer_0 = torch.tensor(np.array(class_num['layer_0']))
        c_layer_1 = torch.tensor(np.array(class_num['layer_1']))
        c_layer_2 = torch.tensor(np.array(class_num['layer_2']))
        c_flatten_0 = torch.flatten(c_layer_0, start_dim=1)
        c_flatten_1 = torch.flatten(c_layer_1, start_dim=1)
        c_flatten_2 = torch.flatten(c_layer_2, start_dim=1)
        flat_class_data = torch.cat((c_flatten_0,c_flatten_1,c_flatten_2), dim=1)
        return flat_class_data

    
    def mask_dataset(self, dataset, limit):
        dataset_mean = torch.mean(dataset, dim=0)
        dataset_mask = torch.where(dataset_mean < limit, torch.tensor(0), torch.tensor(1))
        bool_mask = (dataset_mask == 1)
        self.bool_mask_list = bool_mask
        dataset_processed = dataset[:,bool_mask]
        return dataset_processed
    
    def get_synthetic_dataset(self):
        c1_dir = self.gen_dict[self.gen_one]
        c2_dir = self.gen_dict[self.gen_two]
        gen_c1_data = torch.load(c1_dir)
        gen_c2_data = torch.load(c2_dir)
        gen_c1_tensor = torch.cat(gen_c1_data).cpu()
        gen_c2_tensor = torch.cat(gen_c2_data).cpu()
        # Mask: remove cells that have less 100 MeV mean energy.
        gen_c1_tensor = self.mask_dataset(gen_c1_tensor, 100)
        gen_c2_tensor = self.mask_dataset(gen_c2_tensor, 100)
        print('The shape of masked synthetic gamma data;', gen_c1_tensor.shape)
        print('The shape of masked synthetic eplus data;', gen_c2_tensor.shape)
        gen_c1_labels = torch.ones(gen_c1_tensor.size(0)) # ones
        gen_c2_labels = torch.zeros(gen_c2_tensor.size(0)) # zeros
        gen_dataset = torch.cat((gen_c1_tensor, gen_c2_tensor),dim=0)
        gen_targets = torch.cat((gen_c1_labels, gen_c2_labels), dim=0)
        # shuffle ...
        if self.shuffle==True:
            rand_perm = torch.randperm(gen_dataset.size(0))
            gen_dataset = gen_dataset[rand_perm].float()
            gen_targets = gen_targets[rand_perm]
        # may need to pass the synthetic inputs through a RELU
        return gen_dataset, gen_targets
          
    def get_geant_dataset(self):
        class_one_data = self.flattened_class_data(self.c1)
        class_two_data = self.flattened_class_data(self.c2)
        full_dataset = torch.cat((class_one_data[:,self.bool_mask_list], class_two_data[:,self.bool_mask_list]), dim=0)
        # Getting labels
        c1_labels = torch.ones(class_one_data.size(0)) # ones
        c2_labels = torch.zeros(class_two_data.size(0)) # zeros
        targets = torch.cat((c1_labels, c2_labels), dim=0) # labels

        if self.shuffle==True:
            rand_perm = torch.randperm(full_dataset.size(0))
            full_dataset = full_dataset[rand_perm].float()
            targets = targets[rand_perm]
        return full_dataset, targets
    
    def train_test_split(self, geant = True):
        if geant==True: # split geant data
            full_dataset, targets = self.get_geant_dataset()
        else: # split synthetic data
            full_dataset, targets = self.get_synthetic_dataset()
        num_train_data = int(self.train_prop*full_dataset.size(0))
        train_data = full_dataset[:num_train_data]
        train_targets = targets[:num_train_data]
        valid_data = full_dataset[num_train_data:]
        valid_targets = targets[num_train_data:]
        return train_data, train_targets, valid_data, valid_targets

# %%
class Net(nn.Module):
    def __init__(self, num_features,  num_classes):
        super(Net, self).__init__() 
        self.fc1= nn.Linear(num_features, 512)
        self.nfc1 = nn.BatchNorm1d(512)
        self.drop1 = nn.Dropout(p=0.2)
        
        self.fc2= nn.Linear(512, 1024)
        self.nfc2 = nn.BatchNorm1d(1024)
        self.drop2 = nn.Dropout(p=0.5)
        
        self.fc3= nn.Linear(1024, 2048)
        self.nfc3 = nn.BatchNorm1d(2048)
        self.drop3 = nn.Dropout(p=0.5)
        
        self.fc4= nn.Linear(2048, 1024)
        self.nfc4 = nn.BatchNorm1d(1024)
        self.drop4 = nn.Dropout(p=0.5)
        
        self.fc5= nn.Linear(1024, 128)
        self.nfc5 = nn.BatchNorm1d(128)
        self.drop5 = nn.Dropout(p=0.5)
        
        self.fc6= nn.Linear(128, num_classes)
        
    def forward(self, x):
        h1 = self.nfc1(self.drop1(func.leaky_relu(self.fc1(x)))) 
        h2 = self.nfc2(self.drop2(func.leaky_relu(self.fc2(h1))))
        h3 = self.nfc3(self.drop3(func.leaky_relu(self.fc3(h2))))
        h4 = self.nfc4(self.drop4(func.leaky_relu(self.fc4(h3))))
        h5 = self.drop5(func.leaky_relu(self.fc5(h4)))
        y = torch.sigmoid(self.fc6(h5))
        return y

# %%
def fit(particle_one, particle_two, geant_train = True, num_epochs=40, display_epochs=2, lr=0.075):
    dataloader =  DataProcessor(particle_one, particle_two)
    loss = torch.nn.BCELoss(reduction= 'mean')
    obj_vals= []  
    train_accuracies = []
    valid_accuracies = []
    aux_accuracies = []
    train_data, train_targets, valid_data, valid_targets = dataloader.train_test_split(geant=geant_train)
    model = Net(num_features=sum(dataloader.bool_mask_list).item(), num_classes=1)
    optimizer = optim.Adam(model.parameters(), lr=lr)
    print("Dimensions: train : {0}; target: {1}; valid: {2}; valid_target: {3}".format(train_data.size(), train_targets.size(), valid_data.size(), valid_targets.size()))
    if (geant_train==True):
        auxiliary_test_inputs, auxiliary_targets = dataloader.get_synthetic_dataset()
    else:
        auxiliary_test_inputs, auxiliary_targets = dataloader.get_geant_dataset()
    for epoch in range(num_epochs):   
        # train starts
        model.train()
        model_output = model.forward(train_data).reshape(-1)
        pred = (model_output>0.5).float()
        diff_tensor =  pred - train_targets 
        diff_tensor = torch.abs(diff_tensor)
        train_accuracy = 1-torch.sum(diff_tensor)/pred.size(0)
        train_accuracies.append(train_accuracy)
        model.eval()
        valid_output = model.forward(valid_data).reshape(-1)
        pred_valid = (valid_output>0.5).float()
        diff_tensor_valid =  pred_valid - valid_targets 
        diff_tensor_valid = torch.abs(diff_tensor_valid)
        valid_accuracy = 1-torch.sum(diff_tensor_valid)/pred_valid.size(0)
        valid_accuracies.append(valid_accuracy)
        # valid ends
        # begin auxiliary test
        model.eval() # precaution
        aux_output = model.forward(auxiliary_test_inputs).reshape(-1)
        pred_aux = (aux_output>0.5).float()
        diff_tensor_aux =  pred_aux - auxiliary_targets 
        diff_tensor_aux = torch.abs(diff_tensor_aux)
        aux_accuracy = 1-torch.sum(diff_tensor_aux)/pred_aux.size(0)
        aux_accuracies.append(aux_accuracy)   
        # end auxiliary test
        obj_val = loss(model_output, train_targets)
        optimizer.zero_grad() 
        obj_val.backward()
        optimizer.step() 
        obj_vals.append(obj_val.item())
        if (epoch+1) % display_epochs == 0:
            print ('Epoch [{}/{}]\tTrain Loss :{:.4f}\t train accuracy :{:.4f}%\t validation accuracy :{:.4f}%\t auxiliary class accuracy :{:.4f}%'.format(epoch+1, num_epochs, obj_val.item(), train_accuracy*100, valid_accuracy*100, aux_accuracy*100))
    print("\nTraining Completed")
    return obj_vals, train_accuracies, valid_accuracies, aux_accuracies, num_epochs, model

# %%
# Notes
# lr = 0.0004 is good for e+/gamma+ TRAIN using synthetic data
# MAYBE NEED TO INCREASE LEARNING RATE FOR GEANT_TRAINING with `gamma` & `eplus` particles probably try 0.01
# p+,e+ geant train (geant and synthetic test) -> 0.0005, 150 epochs more than enoughh
# e+/pi+ and e+/gamma

# %%
obj_vals, train_accuracies, valid_accuracies, aux_accuracies, num_epochs, model = fit(
    'gamma', 'eplus', 
    geant_train=False, 
    num_epochs=800,  
    display_epochs=1, 
    lr=0.0004)
# Out:
# The shape of masked synthetic gamma data; torch.Size([51200, 22])
# The shape of masked synthetic eplus data; torch.Size([51200, 22])
# Dimensions: train : torch.Size([71680, 22]); target: torch.Size([71680]); valid: torch.Size([30720, 22]); valid_target: torch.Size([30720])
# Epoch [1/800]	Train Loss :0.7050	 train accuracy :49.3624%	 validation accuracy :49.8014%	 auxiliary class accuracy :49.5745%
# Epoch [2/800]	Train Loss :0.6150	 train accuracy :69.3959%	 validation accuracy :72.1517%	 auxiliary class accuracy :58.3750%
# Epoch [3/800]	Train Loss :0.5364	 train accuracy :75.0014%	 validation accuracy :77.3763%	 auxiliary class accuracy :62.5370%
# Epoch [4/800]	Train Loss :0.4876	 train accuracy :76.7871%	 validation accuracy :77.1842%	 auxiliary class accuracy :62.9925%
# Epoch [5/800]	Train Loss :0.4752	 train accuracy :77.7623%	 validation accuracy :76.8066%	 auxiliary class accuracy :63.1020%
# Epoch [6/800]	Train Loss :0.4755	 train accuracy :77.8139%	 validation accuracy :74.8372%	 auxiliary class accuracy :63.7000%
# Epoch [7/800]	Train Loss :0.4711	 train accuracy :78.3663%	 validation accuracy :74.4629%	 auxiliary class accuracy :63.4445%
# Epoch [8/800]	Train Loss :0.4611	 train accuracy :78.5742%	 validation accuracy :73.2975%	 auxiliary class accuracy :63.4810%
# Epoch [9/800]	Train Loss :0.4588	 train accuracy :78.5059%	 validation accuracy :72.6204%	 auxiliary class accuracy :63.2350%
# Epoch [10/800]	Train Loss :0.4516	 train accuracy :78.7723%	 validation accuracy :73.3691%	 auxiliary class accuracy :62.8905%
# Epoch [11/800]	Train Loss :0.4512	 train accuracy :78.8993%	 validation accuracy :74.1309%	 auxiliary class accuracy :62.3120%
# Epoch [12/800]	Train Loss :0.4477	 train accuracy :79.1867%	 validation accuracy :74.8372%	 auxiliary class accuracy :61.7195%
# Epoch [13/800]	Train Loss :0.4436	 train accuracy :79.4517%	 validation accuracy :76.3900%	 auxiliary class accuracy :60.8795%
# Epoch [14/800]	Train Loss :0.4396	 train accuracy :79.8172%	 validation accuracy :78.4277%	 auxiliary class accuracy :59.9720%
# Epoch [15/800]	Train Loss :0.4335	 train accuracy :80.1772%	 validation accuracy :80.0228%	 auxiliary class accuracy :59.1675%
# Epoch [16/800]	Train Loss :0.4252	 train accuracy :80.5064%	 validation accuracy :80.8008%	 auxiliary class accuracy :58.5840%
# Epoch [17/800]	Train Loss :0.4199	 train accuracy :80.8580%	 validation accuracy :81.0970%	 auxiliary class accuracy :57.9795%
# Epoch [18/800]	Train Loss :0.4135	 train accuracy :81.3114%	 validation accuracy :81.4095%	 auxiliary class accuracy :57.3425%
# Epoch [19/800]	Train Loss :0.4027	 train accuracy :82.0829%	 validation accuracy :82.4284%	 auxiliary class accuracy :56.6685%
# Epoch [20/800]	Train Loss :0.3970	 train accuracy :82.3800%	 validation accuracy :82.7637%	 auxiliary class accuracy :55.9300%
# Epoch [21/800]	Train Loss :0.3860	 train accuracy :82.9171%	 validation accuracy :83.7956%	 auxiliary class accuracy :55.2245%
# Epoch [22/800]	Train Loss :0.3763	 train accuracy :83.5282%	 validation accuracy :84.5898%	 auxiliary class accuracy :54.5435%
# Epoch [23/800]	Train Loss :0.3680	 train accuracy :83.8728%	 validation accuracy :86.0645%	 auxiliary class accuracy :53.9590%
# Epoch [24/800]	Train Loss :0.3693	 train accuracy :84.1350%	 validation accuracy :86.8880%	 auxiliary class accuracy :53.4295%
# Epoch [25/800]	Train Loss :0.3789	 train accuracy :83.3775%	 validation accuracy :75.8724%	 auxiliary class accuracy :53.2795%
# Epoch [26/800]	Train Loss :0.3664	 train accuracy :84.2201%	 validation accuracy :86.5951%	 auxiliary class accuracy :53.2985%
# Epoch [27/800]	Train Loss :0.3472	 train accuracy :85.2469%	 validation accuracy :86.8815%	 auxiliary class accuracy :53.5250%
# Epoch [28/800]	Train Loss :0.3536	 train accuracy :84.7224%	 validation accuracy :81.6178%	 auxiliary class accuracy :53.7750%
# Epoch [29/800]	Train Loss :0.3382	 train accuracy :85.6041%	 validation accuracy :86.6244%	 auxiliary class accuracy :53.9730%
# Epoch [30/800]	Train Loss :0.3405	 train accuracy :85.5497%	 validation accuracy :86.5690%	 auxiliary class accuracy :54.0765%
# Epoch [31/800]	Train Loss :0.3288	 train accuracy :86.3881%	 validation accuracy :88.3203%	 auxiliary class accuracy :54.1000%
# Epoch [32/800]	Train Loss :0.3277	 train accuracy :86.3365%	 validation accuracy :87.1810%	 auxiliary class accuracy :54.1650%
# Epoch [33/800]	Train Loss :0.3232	 train accuracy :86.3825%	 validation accuracy :88.1673%	 auxiliary class accuracy :54.2285%
# Epoch [34/800]	Train Loss :0.3169	 train accuracy :86.8959%	 validation accuracy :88.5221%	 auxiliary class accuracy :54.3045%
# Epoch [35/800]	Train Loss :0.3164	 train accuracy :86.7690%	 validation accuracy :87.2494%	 auxiliary class accuracy :54.3720%
# Epoch [36/800]	Train Loss :0.3063	 train accuracy :87.2196%	 validation accuracy :88.5189%	 auxiliary class accuracy :54.4670%
# Epoch [37/800]	Train Loss :0.3055	 train accuracy :87.3591%	 validation accuracy :88.5547%	 auxiliary class accuracy :54.5035%
# Epoch [38/800]	Train Loss :0.2980	 train accuracy :87.7679%	 validation accuracy :89.5345%	 auxiliary class accuracy :54.3625%
# Epoch [39/800]	Train Loss :0.3004	 train accuracy :87.6270%	 validation accuracy :89.2546%	 auxiliary class accuracy :54.2850%
# Epoch [40/800]	Train Loss :0.2941	 train accuracy :87.9701%	 validation accuracy :89.9219%	 auxiliary class accuracy :54.2520%
# Epoch [41/800]	Train Loss :0.2932	 train accuracy :87.8474%	 validation accuracy :89.0300%	 auxiliary class accuracy :54.2190%
# Epoch [42/800]	Train Loss :0.2836	 train accuracy :88.5672%	 validation accuracy :89.4954%	 auxiliary class accuracy :54.1660%
# Epoch [43/800]	Train Loss :0.2839	 train accuracy :88.3873%	 validation accuracy :89.7233%	 auxiliary class accuracy :54.1300%
# Epoch [44/800]	Train Loss :0.2783	 train accuracy :88.6635%	 validation accuracy :89.9284%	 auxiliary class accuracy :54.2215%
# Epoch [45/800]	Train Loss :0.2730	 train accuracy :89.0820%	 validation accuracy :89.7526%	 auxiliary class accuracy :54.2785%
# Epoch [46/800]	Train Loss :0.2719	 train accuracy :89.1239%	 validation accuracy :90.1693%	 auxiliary class accuracy :54.2835%
# Epoch [47/800]	Train Loss :0.2655	 train accuracy :89.2620%	 validation accuracy :91.0514%	 auxiliary class accuracy :54.2160%
# Epoch [48/800]	Train Loss :0.2647	 train accuracy :89.3066%	 validation accuracy :90.9017%	 auxiliary class accuracy :54.1810%
# Epoch [49/800]	Train Loss :0.2653	 train accuracy :89.4155%	 validation accuracy :90.4395%	 auxiliary class accuracy :54.2085%
# Epoch [50/800]	Train Loss :0.2561	 train accuracy :89.6624%	 validation accuracy :91.2044%	 auxiliary class accuracy :54.2060%
# Epoch [51/800]	Train Loss :0.2575	 train accuracy :89.6735%	 validation accuracy :90.9993%	 auxiliary class accuracy :54.2630%
# Epoch [52/800]	Train Loss :0.2534	 train accuracy :89.9121%	 validation accuracy :90.4036%	 auxiliary class accuracy :54.3240%
# Epoch [53/800]	Train Loss :0.2457	 train accuracy :90.2469%	 validation accuracy :91.0514%	 auxiliary class accuracy :54.2955%
# Epoch [54/800]	Train Loss :0.2449	 train accuracy :90.2986%	 validation accuracy :91.3997%	 auxiliary class accuracy :54.2450%
# Epoch [55/800]	Train Loss :0.2403	 train accuracy :90.5887%	 validation accuracy :90.9538%	 auxiliary class accuracy :54.2660%
# Epoch [56/800]	Train Loss :0.2387	 train accuracy :90.5050%	 validation accuracy :90.9505%	 auxiliary class accuracy :54.2925%
# Epoch [57/800]	Train Loss :0.2309	 train accuracy :91.0379%	 validation accuracy :91.8717%	 auxiliary class accuracy :54.3225%
# Epoch [58/800]	Train Loss :0.2279	 train accuracy :91.1649%	 validation accuracy :91.9857%	 auxiliary class accuracy :54.4040%
# Epoch [59/800]	Train Loss :0.2228	 train accuracy :91.4160%	 validation accuracy :92.0931%	 auxiliary class accuracy :54.4445%
# Epoch [60/800]	Train Loss :0.2175	 train accuracy :91.5890%	 validation accuracy :92.1484%	 auxiliary class accuracy :54.4915%
# Epoch [61/800]	Train Loss :0.2110	 train accuracy :91.8332%	 validation accuracy :92.0020%	 auxiliary class accuracy :54.5645%
# Epoch [62/800]	Train Loss :0.2041	 train accuracy :92.0020%	 validation accuracy :92.3242%	 auxiliary class accuracy :54.8000%
# Epoch [63/800]	Train Loss :0.2026	 train accuracy :92.0787%	 validation accuracy :92.9915%	 auxiliary class accuracy :55.0285%
# Epoch [64/800]	Train Loss :0.1996	 train accuracy :92.2991%	 validation accuracy :93.2520%	 auxiliary class accuracy :55.1700%
# Epoch [65/800]	Train Loss :0.1953	 train accuracy :92.4107%	 validation accuracy :93.4766%	 auxiliary class accuracy :55.2975%
# Epoch [66/800]	Train Loss :0.1901	 train accuracy :92.6311%	 validation accuracy :93.3008%	 auxiliary class accuracy :55.2870%
# Epoch [67/800]	Train Loss :0.2070	 train accuracy :91.4188%	 validation accuracy :92.3405%	 auxiliary class accuracy :55.3080%
# Epoch [68/800]	Train Loss :0.2656	 train accuracy :88.8546%	 validation accuracy :80.7617%	 auxiliary class accuracy :55.4395%
# Epoch [69/800]	Train Loss :0.2043	 train accuracy :91.7606%	 validation accuracy :91.7806%	 auxiliary class accuracy :55.5245%
# Epoch [70/800]	Train Loss :0.2255	 train accuracy :90.5580%	 validation accuracy :90.2962%	 auxiliary class accuracy :55.5435%
# Epoch [71/800]	Train Loss :0.1950	 train accuracy :92.0592%	 validation accuracy :91.5592%	 auxiliary class accuracy :55.5980%
# Epoch [72/800]	Train Loss :0.2135	 train accuracy :90.8496%	 validation accuracy :87.1908%	 auxiliary class accuracy :55.5560%
# Epoch [73/800]	Train Loss :0.1895	 train accuracy :92.4316%	 validation accuracy :92.3958%	 auxiliary class accuracy :55.5705%
# Epoch [74/800]	Train Loss :0.2053	 train accuracy :91.7899%	 validation accuracy :92.4089%	 auxiliary class accuracy :55.4120%
# Epoch [75/800]	Train Loss :0.1917	 train accuracy :92.4065%	 validation accuracy :93.3203%	 auxiliary class accuracy :55.3515%
# Epoch [76/800]	Train Loss :0.1824	 train accuracy :92.8125%	 validation accuracy :92.0378%	 auxiliary class accuracy :55.4210%
# Epoch [77/800]	Train Loss :0.1871	 train accuracy :92.6130%	 validation accuracy :91.1263%	 auxiliary class accuracy :55.5110%
# Epoch [78/800]	Train Loss :0.1772	 train accuracy :93.2017%	 validation accuracy :93.9876%	 auxiliary class accuracy :55.6840%
# Epoch [79/800]	Train Loss :0.1783	 train accuracy :92.9492%	 validation accuracy :93.9583%	 auxiliary class accuracy :55.8010%
# Epoch [80/800]	Train Loss :0.1716	 train accuracy :93.2910%	 validation accuracy :94.2871%	 auxiliary class accuracy :55.8485%
# Epoch [81/800]	Train Loss :0.1719	 train accuracy :93.2952%	 validation accuracy :92.8190%	 auxiliary class accuracy :56.0080%
# Epoch [82/800]	Train Loss :0.1709	 train accuracy :93.3357%	 validation accuracy :93.8184%	 auxiliary class accuracy :56.1045%
# Epoch [83/800]	Train Loss :0.1612	 train accuracy :93.5575%	 validation accuracy :94.9740%	 auxiliary class accuracy :56.2320%
# Epoch [84/800]	Train Loss :0.1584	 train accuracy :93.7640%	 validation accuracy :95.0977%	 auxiliary class accuracy :56.3470%
# Epoch [85/800]	Train Loss :0.1606	 train accuracy :93.6649%	 validation accuracy :95.0651%	 auxiliary class accuracy :56.4115%
# Epoch [86/800]	Train Loss :0.1544	 train accuracy :93.7960%	 validation accuracy :94.5378%	 auxiliary class accuracy :56.4705%
# Epoch [87/800]	Train Loss :0.1520	 train accuracy :93.9551%	 validation accuracy :94.2155%	 auxiliary class accuracy :56.5275%
# Epoch [88/800]	Train Loss :0.1479	 train accuracy :94.2927%	 validation accuracy :93.6263%	 auxiliary class accuracy :56.5130%
# Epoch [89/800]	Train Loss :0.1481	 train accuracy :94.2048%	 validation accuracy :94.9251%	 auxiliary class accuracy :56.5845%
# Epoch [90/800]	Train Loss :0.1450	 train accuracy :94.1950%	 validation accuracy :95.3874%	 auxiliary class accuracy :56.5905%
# Epoch [91/800]	Train Loss :0.1401	 train accuracy :94.5773%	 validation accuracy :95.2279%	 auxiliary class accuracy :56.6170%
# Epoch [92/800]	Train Loss :0.1403	 train accuracy :94.4643%	 validation accuracy :95.5046%	 auxiliary class accuracy :56.6270%
# Epoch [93/800]	Train Loss :0.1337	 train accuracy :94.7489%	 validation accuracy :95.6120%	 auxiliary class accuracy :56.6145%
# Epoch [94/800]	Train Loss :0.1358	 train accuracy :94.6443%	 validation accuracy :95.7324%	 auxiliary class accuracy :56.6100%
# Epoch [95/800]	Train Loss :0.1323	 train accuracy :94.7447%	 validation accuracy :95.5371%	 auxiliary class accuracy :56.5790%
# Epoch [96/800]	Train Loss :0.1340	 train accuracy :94.8075%	 validation accuracy :93.2943%	 auxiliary class accuracy :56.6745%
# Epoch [97/800]	Train Loss :0.1325	 train accuracy :94.7656%	 validation accuracy :94.5801%	 auxiliary class accuracy :56.7820%
# Epoch [98/800]	Train Loss :0.1270	 train accuracy :95.0767%	 validation accuracy :94.3717%	 auxiliary class accuracy :56.9365%
# Epoch [99/800]	Train Loss :0.1226	 train accuracy :95.1883%	 validation accuracy :95.4720%	 auxiliary class accuracy :56.9285%
# Epoch [100/800]	Train Loss :0.1224	 train accuracy :95.2734%	 validation accuracy :95.5957%	 auxiliary class accuracy :56.8910%
# Epoch [101/800]	Train Loss :0.1181	 train accuracy :95.3850%	 validation accuracy :95.7194%	 auxiliary class accuracy :56.8655%
# Epoch [102/800]	Train Loss :0.1166	 train accuracy :95.4841%	 validation accuracy :95.8919%	 auxiliary class accuracy :56.7710%
# Epoch [103/800]	Train Loss :0.1160	 train accuracy :95.3948%	 validation accuracy :95.9831%	 auxiliary class accuracy :56.6885%
# Epoch [104/800]	Train Loss :0.1134	 train accuracy :95.7059%	 validation accuracy :96.1654%	 auxiliary class accuracy :56.6230%
# Epoch [105/800]	Train Loss :0.1112	 train accuracy :95.7575%	 validation accuracy :96.0189%	 auxiliary class accuracy :56.5245%
# Epoch [106/800]	Train Loss :0.1110	 train accuracy :95.8105%	 validation accuracy :95.9277%	 auxiliary class accuracy :56.4935%
# Epoch [107/800]	Train Loss :0.1107	 train accuracy :95.7492%	 validation accuracy :96.4290%	 auxiliary class accuracy :56.3915%
# Epoch [108/800]	Train Loss :0.1161	 train accuracy :95.4381%	 validation accuracy :95.1204%	 auxiliary class accuracy :56.3685%
# Epoch [109/800]	Train Loss :0.1396	 train accuracy :94.5089%	 validation accuracy :95.9049%	 auxiliary class accuracy :56.2810%
# Epoch [110/800]	Train Loss :0.1552	 train accuracy :93.7946%	 validation accuracy :87.3242%	 auxiliary class accuracy :56.3580%
# Epoch [111/800]	Train Loss :0.1126	 train accuracy :95.6278%	 validation accuracy :96.3379%	 auxiliary class accuracy :56.3975%
# Epoch [112/800]	Train Loss :0.1307	 train accuracy :94.8800%	 validation accuracy :95.1042%	 auxiliary class accuracy :56.4245%
# Epoch [113/800]	Train Loss :0.1196	 train accuracy :95.2260%	 validation accuracy :96.1784%	 auxiliary class accuracy :56.4385%
# Epoch [114/800]	Train Loss :0.1214	 train accuracy :95.2288%	 validation accuracy :95.6510%	 auxiliary class accuracy :56.3895%
# Epoch [115/800]	Train Loss :0.1113	 train accuracy :95.7394%	 validation accuracy :96.7480%	 auxiliary class accuracy :56.2310%
# Epoch [116/800]	Train Loss :0.1194	 train accuracy :95.3320%	 validation accuracy :96.5625%	 auxiliary class accuracy :56.0485%
# Epoch [117/800]	Train Loss :0.1085	 train accuracy :95.8454%	 validation accuracy :95.8659%	 auxiliary class accuracy :56.0500%
# Epoch [118/800]	Train Loss :0.1087	 train accuracy :95.7561%	 validation accuracy :95.6608%	 auxiliary class accuracy :56.0570%
# Epoch [119/800]	Train Loss :0.1064	 train accuracy :95.9570%	 validation accuracy :96.9043%	 auxiliary class accuracy :55.9885%
# Epoch [120/800]	Train Loss :0.1053	 train accuracy :95.9989%	 validation accuracy :97.0475%	 auxiliary class accuracy :55.8985%
# Epoch [121/800]	Train Loss :0.1040	 train accuracy :95.9793%	 validation accuracy :96.6406%	 auxiliary class accuracy :55.9110%
# Epoch [122/800]	Train Loss :0.1055	 train accuracy :95.9361%	 validation accuracy :96.8587%	 auxiliary class accuracy :56.0545%
# Epoch [123/800]	Train Loss :0.1023	 train accuracy :96.1468%	 validation accuracy :97.2266%	 auxiliary class accuracy :56.1345%
# Epoch [124/800]	Train Loss :0.0994	 train accuracy :96.1719%	 validation accuracy :97.5163%	 auxiliary class accuracy :56.2505%
# Epoch [125/800]	Train Loss :0.1021	 train accuracy :96.0575%	 validation accuracy :97.1061%	 auxiliary class accuracy :56.1440%
# Epoch [126/800]	Train Loss :0.0971	 train accuracy :96.2584%	 validation accuracy :97.5879%	 auxiliary class accuracy :55.9275%
# Epoch [127/800]	Train Loss :0.1018	 train accuracy :96.0910%	 validation accuracy :97.6042%	 auxiliary class accuracy :55.7870%
# Epoch [128/800]	Train Loss :0.0990	 train accuracy :96.1886%	 validation accuracy :97.6725%	 auxiliary class accuracy :55.7165%
# Epoch [129/800]	Train Loss :0.0939	 train accuracy :96.3825%	 validation accuracy :97.7897%	 auxiliary class accuracy :55.6170%
# Epoch [130/800]	Train Loss :0.0981	 train accuracy :96.1914%	 validation accuracy :97.7572%	 auxiliary class accuracy :55.4640%
# Epoch [131/800]	Train Loss :0.0949	 train accuracy :96.4844%	 validation accuracy :97.5326%	 auxiliary class accuracy :55.3810%
# Epoch [132/800]	Train Loss :0.0923	 train accuracy :96.5346%	 validation accuracy :97.6074%	 auxiliary class accuracy :55.2500%
# Epoch [133/800]	Train Loss :0.0937	 train accuracy :96.4579%	 validation accuracy :97.7246%	 auxiliary class accuracy :55.1315%
# Epoch [134/800]	Train Loss :0.0916	 train accuracy :96.5388%	 validation accuracy :97.4349%	 auxiliary class accuracy :55.0435%
# Epoch [135/800]	Train Loss :0.0902	 train accuracy :96.6867%	 validation accuracy :97.5065%	 auxiliary class accuracy :55.0295%
# Epoch [136/800]	Train Loss :0.0882	 train accuracy :96.6337%	 validation accuracy :97.7995%	 auxiliary class accuracy :55.0315%
# Epoch [137/800]	Train Loss :0.0895	 train accuracy :96.6337%	 validation accuracy :97.7051%	 auxiliary class accuracy :55.1015%
# Epoch [138/800]	Train Loss :0.0883	 train accuracy :96.6713%	 validation accuracy :97.8190%	 auxiliary class accuracy :55.0935%
# Epoch [139/800]	Train Loss :0.0882	 train accuracy :96.6727%	 validation accuracy :97.9427%	 auxiliary class accuracy :55.0720%
# Epoch [140/800]	Train Loss :0.0868	 train accuracy :96.7132%	 validation accuracy :97.8418%	 auxiliary class accuracy :55.0895%
# Epoch [141/800]	Train Loss :0.0837	 train accuracy :96.8136%	 validation accuracy :98.0827%	 auxiliary class accuracy :55.0950%
# Epoch [142/800]	Train Loss :0.0855	 train accuracy :96.7773%	 validation accuracy :98.1673%	 auxiliary class accuracy :55.0615%
# Epoch [143/800]	Train Loss :0.0841	 train accuracy :96.7997%	 validation accuracy :97.9102%	 auxiliary class accuracy :55.0740%
# Epoch [144/800]	Train Loss :0.0824	 train accuracy :96.9364%	 validation accuracy :98.1250%	 auxiliary class accuracy :55.0680%
# Epoch [145/800]	Train Loss :0.0824	 train accuracy :96.8945%	 validation accuracy :98.0566%	 auxiliary class accuracy :55.0555%
# Epoch [146/800]	Train Loss :0.0827	 train accuracy :96.8876%	 validation accuracy :97.7344%	 auxiliary class accuracy :55.0950%
# Epoch [147/800]	Train Loss :0.0830	 train accuracy :96.8820%	 validation accuracy :98.0697%	 auxiliary class accuracy :55.0895%
# Epoch [148/800]	Train Loss :0.0816	 train accuracy :96.9573%	 validation accuracy :97.9492%	 auxiliary class accuracy :55.0850%
# Epoch [149/800]	Train Loss :0.0814	 train accuracy :96.9545%	 validation accuracy :97.6270%	 auxiliary class accuracy :55.0230%
# Epoch [150/800]	Train Loss :0.0796	 train accuracy :97.0410%	 validation accuracy :97.9525%	 auxiliary class accuracy :54.9300%
# Epoch [151/800]	Train Loss :0.0783	 train accuracy :97.0550%	 validation accuracy :97.5684%	 auxiliary class accuracy :54.9645%
# Epoch [152/800]	Train Loss :0.0769	 train accuracy :97.1303%	 validation accuracy :98.5286%	 auxiliary class accuracy :54.9045%
# Epoch [153/800]	Train Loss :0.0757	 train accuracy :97.2112%	 validation accuracy :98.5905%	 auxiliary class accuracy :54.9405%
# Epoch [154/800]	Train Loss :0.0761	 train accuracy :97.2014%	 validation accuracy :98.1999%	 auxiliary class accuracy :54.9810%
# Epoch [155/800]	Train Loss :0.0778	 train accuracy :97.0968%	 validation accuracy :98.4700%	 auxiliary class accuracy :54.8970%
# Epoch [156/800]	Train Loss :0.0768	 train accuracy :97.1289%	 validation accuracy :97.8841%	 auxiliary class accuracy :54.9150%
# Epoch [157/800]	Train Loss :0.0792	 train accuracy :97.0773%	 validation accuracy :98.5645%	 auxiliary class accuracy :54.7975%
# Epoch [158/800]	Train Loss :0.0751	 train accuracy :97.2545%	 validation accuracy :98.3887%	 auxiliary class accuracy :54.8620%
# Epoch [159/800]	Train Loss :0.0734	 train accuracy :97.2377%	 validation accuracy :98.2780%	 auxiliary class accuracy :54.8155%
# Epoch [160/800]	Train Loss :0.0767	 train accuracy :97.1708%	 validation accuracy :98.5938%	 auxiliary class accuracy :54.6915%
# Epoch [161/800]	Train Loss :0.0742	 train accuracy :97.3145%	 validation accuracy :97.9883%	 auxiliary class accuracy :54.7770%
# Epoch [162/800]	Train Loss :0.0744	 train accuracy :97.2182%	 validation accuracy :98.7435%	 auxiliary class accuracy :54.6870%
# Epoch [163/800]	Train Loss :0.0719	 train accuracy :97.3940%	 validation accuracy :98.7207%	 auxiliary class accuracy :54.8075%
# Epoch [164/800]	Train Loss :0.0722	 train accuracy :97.3145%	 validation accuracy :98.7533%	 auxiliary class accuracy :54.7860%
# Epoch [165/800]	Train Loss :0.0722	 train accuracy :97.3172%	 validation accuracy :98.7240%	 auxiliary class accuracy :54.7400%
# Epoch [166/800]	Train Loss :0.0731	 train accuracy :97.2796%	 validation accuracy :97.7865%	 auxiliary class accuracy :54.7630%
# Epoch [167/800]	Train Loss :0.0765	 train accuracy :97.1680%	 validation accuracy :98.7207%	 auxiliary class accuracy :54.6610%
# Epoch [168/800]	Train Loss :0.0760	 train accuracy :97.0940%	 validation accuracy :97.7604%	 auxiliary class accuracy :54.8380%
# Epoch [169/800]	Train Loss :0.0719	 train accuracy :97.3814%	 validation accuracy :98.7533%	 auxiliary class accuracy :54.7735%
# Epoch [170/800]	Train Loss :0.0682	 train accuracy :97.5000%	 validation accuracy :98.4733%	 auxiliary class accuracy :54.9760%
# Epoch [171/800]	Train Loss :0.0689	 train accuracy :97.5139%	 validation accuracy :97.6204%	 auxiliary class accuracy :55.1205%
# Epoch [172/800]	Train Loss :0.0692	 train accuracy :97.4121%	 validation accuracy :98.3529%	 auxiliary class accuracy :55.1500%
# Epoch [173/800]	Train Loss :0.0684	 train accuracy :97.4693%	 validation accuracy :98.2682%	 auxiliary class accuracy :55.2875%
# Epoch [174/800]	Train Loss :0.0676	 train accuracy :97.4986%	 validation accuracy :98.6165%	 auxiliary class accuracy :55.4120%
# Epoch [175/800]	Train Loss :0.0686	 train accuracy :97.5056%	 validation accuracy :98.8965%	 auxiliary class accuracy :55.4245%
# Epoch [176/800]	Train Loss :0.0656	 train accuracy :97.6130%	 validation accuracy :97.8809%	 auxiliary class accuracy :55.4660%
# Epoch [177/800]	Train Loss :0.0662	 train accuracy :97.6130%	 validation accuracy :98.4115%	 auxiliary class accuracy :55.3900%
# Epoch [178/800]	Train Loss :0.0660	 train accuracy :97.6116%	 validation accuracy :98.4961%	 auxiliary class accuracy :55.3765%
# Epoch [179/800]	Train Loss :0.0654	 train accuracy :97.5739%	 validation accuracy :98.9030%	 auxiliary class accuracy :55.3365%
# Epoch [180/800]	Train Loss :0.0647	 train accuracy :97.6576%	 validation accuracy :98.9030%	 auxiliary class accuracy :55.2515%
# Epoch [181/800]	Train Loss :0.0646	 train accuracy :97.6674%	 validation accuracy :98.4050%	 auxiliary class accuracy :55.2370%
# Epoch [182/800]	Train Loss :0.0655	 train accuracy :97.5977%	 validation accuracy :98.7044%	 auxiliary class accuracy :55.1590%
# Epoch [183/800]	Train Loss :0.0631	 train accuracy :97.6897%	 validation accuracy :98.7500%	 auxiliary class accuracy :55.2290%
# Epoch [184/800]	Train Loss :0.0624	 train accuracy :97.7748%	 validation accuracy :98.9355%	 auxiliary class accuracy :55.2725%
# Epoch [185/800]	Train Loss :0.0614	 train accuracy :97.7748%	 validation accuracy :98.9876%	 auxiliary class accuracy :55.2895%
# Epoch [186/800]	Train Loss :0.0619	 train accuracy :97.7358%	 validation accuracy :98.5514%	 auxiliary class accuracy :55.2850%
# Epoch [187/800]	Train Loss :0.0664	 train accuracy :97.5377%	 validation accuracy :98.9486%	 auxiliary class accuracy :55.1630%
# Epoch [188/800]	Train Loss :0.0741	 train accuracy :97.1917%	 validation accuracy :98.4538%	 auxiliary class accuracy :55.2410%
# Epoch [189/800]	Train Loss :0.0834	 train accuracy :96.8373%	 validation accuracy :98.2617%	 auxiliary class accuracy :55.0840%
# Epoch [190/800]	Train Loss :0.0726	 train accuracy :97.3200%	 validation accuracy :98.1869%	 auxiliary class accuracy :55.2970%
# Epoch [191/800]	Train Loss :0.0684	 train accuracy :97.4609%	 validation accuracy :98.4082%	 auxiliary class accuracy :55.4310%
# Epoch [192/800]	Train Loss :0.0747	 train accuracy :97.2238%	 validation accuracy :98.5677%	 auxiliary class accuracy :55.4185%
# Epoch [193/800]	Train Loss :0.0630	 train accuracy :97.6604%	 validation accuracy :98.6491%	 auxiliary class accuracy :55.6120%
# Epoch [194/800]	Train Loss :0.0763	 train accuracy :97.1247%	 validation accuracy :96.4779%	 auxiliary class accuracy :55.6845%
# Epoch [195/800]	Train Loss :0.0735	 train accuracy :97.2587%	 validation accuracy :98.7402%	 auxiliary class accuracy :55.6015%
# Epoch [196/800]	Train Loss :0.0618	 train accuracy :97.7734%	 validation accuracy :98.8639%	 auxiliary class accuracy :55.6250%
# Epoch [197/800]	Train Loss :0.0726	 train accuracy :97.3047%	 validation accuracy :98.6816%	 auxiliary class accuracy :55.8015%
# Epoch [198/800]	Train Loss :0.0638	 train accuracy :97.6897%	 validation accuracy :98.6784%	 auxiliary class accuracy :55.7175%
# Epoch [199/800]	Train Loss :0.0643	 train accuracy :97.7204%	 validation accuracy :98.9258%	 auxiliary class accuracy :55.6945%
# Epoch [200/800]	Train Loss :0.0675	 train accuracy :97.4386%	 validation accuracy :98.6816%	 auxiliary class accuracy :55.6470%
# Epoch [201/800]	Train Loss :0.0615	 train accuracy :97.7204%	 validation accuracy :99.0267%	 auxiliary class accuracy :55.5165%
# Epoch [202/800]	Train Loss :0.0644	 train accuracy :97.6046%	 validation accuracy :98.8835%	 auxiliary class accuracy :55.3695%
# Epoch [203/800]	Train Loss :0.0634	 train accuracy :97.7567%	 validation accuracy :98.6784%	 auxiliary class accuracy :55.3405%
# Epoch [204/800]	Train Loss :0.0611	 train accuracy :97.7790%	 validation accuracy :98.9518%	 auxiliary class accuracy :55.2415%
# Epoch [205/800]	Train Loss :0.0638	 train accuracy :97.6353%	 validation accuracy :98.6947%	 auxiliary class accuracy :55.0950%
# Epoch [206/800]	Train Loss :0.0586	 train accuracy :97.9088%	 validation accuracy :98.7174%	 auxiliary class accuracy :55.0535%
# Epoch [207/800]	Train Loss :0.0578	 train accuracy :97.9492%	 validation accuracy :98.7109%	 auxiliary class accuracy :55.0330%
# Epoch [208/800]	Train Loss :0.0612	 train accuracy :97.7148%	 validation accuracy :98.9128%	 auxiliary class accuracy :54.9625%
# Epoch [209/800]	Train Loss :0.0571	 train accuracy :97.9715%	 validation accuracy :99.0137%	 auxiliary class accuracy :55.0295%
# Epoch [210/800]	Train Loss :0.0564	 train accuracy :97.9492%	 validation accuracy :99.0299%	 auxiliary class accuracy :55.0705%
# Epoch [211/800]	Train Loss :0.0579	 train accuracy :97.8544%	 validation accuracy :98.8346%	 auxiliary class accuracy :55.0335%
# Epoch [212/800]	Train Loss :0.0536	 train accuracy :98.0525%	 validation accuracy :99.1178%	 auxiliary class accuracy :55.0420%
# Epoch [213/800]	Train Loss :0.0579	 train accuracy :97.9450%	 validation accuracy :99.0137%	 auxiliary class accuracy :55.0050%
# Epoch [214/800]	Train Loss :0.0590	 train accuracy :97.8139%	 validation accuracy :99.0592%	 auxiliary class accuracy :54.8600%
# Epoch [215/800]	Train Loss :0.0540	 train accuracy :98.0622%	 validation accuracy :99.1374%	 auxiliary class accuracy :54.9035%
# Epoch [216/800]	Train Loss :0.0546	 train accuracy :98.0246%	 validation accuracy :99.1699%	 auxiliary class accuracy :54.9550%
# Epoch [217/800]	Train Loss :0.0558	 train accuracy :97.9911%	 validation accuracy :98.9941%	 auxiliary class accuracy :54.8840%
# Epoch [218/800]	Train Loss :0.0517	 train accuracy :98.1599%	 validation accuracy :99.1699%	 auxiliary class accuracy :54.9390%
# Epoch [219/800]	Train Loss :0.0530	 train accuracy :98.0636%	 validation accuracy :99.0625%	 auxiliary class accuracy :54.9360%
# Epoch [220/800]	Train Loss :0.0535	 train accuracy :98.0929%	 validation accuracy :99.0788%	 auxiliary class accuracy :54.9345%
# Epoch [221/800]	Train Loss :0.0514	 train accuracy :98.1306%	 validation accuracy :99.2546%	 auxiliary class accuracy :55.1560%
# Epoch [222/800]	Train Loss :0.0508	 train accuracy :98.2045%	 validation accuracy :99.1829%	 auxiliary class accuracy :55.1795%
# Epoch [223/800]	Train Loss :0.0510	 train accuracy :98.2031%	 validation accuracy :99.2122%	 auxiliary class accuracy :55.2635%
# Epoch [224/800]	Train Loss :0.0523	 train accuracy :98.0901%	 validation accuracy :99.1667%	 auxiliary class accuracy :55.4470%
# Epoch [225/800]	Train Loss :0.0507	 train accuracy :98.2101%	 validation accuracy :99.1797%	 auxiliary class accuracy :55.4340%
# Epoch [226/800]	Train Loss :0.0497	 train accuracy :98.2603%	 validation accuracy :99.1927%	 auxiliary class accuracy :55.5430%
# Epoch [227/800]	Train Loss :0.0489	 train accuracy :98.2338%	 validation accuracy :99.2220%	 auxiliary class accuracy :55.5540%
# Epoch [228/800]	Train Loss :0.0488	 train accuracy :98.2087%	 validation accuracy :99.2415%	 auxiliary class accuracy :55.5280%
# Epoch [229/800]	Train Loss :0.0497	 train accuracy :98.1962%	 validation accuracy :99.1895%	 auxiliary class accuracy :55.4425%
# Epoch [230/800]	Train Loss :0.0475	 train accuracy :98.3050%	 validation accuracy :99.2871%	 auxiliary class accuracy :55.3625%
# Epoch [231/800]	Train Loss :0.0494	 train accuracy :98.2631%	 validation accuracy :99.2871%	 auxiliary class accuracy :55.3280%
# Epoch [232/800]	Train Loss :0.0465	 train accuracy :98.3133%	 validation accuracy :99.2806%	 auxiliary class accuracy :55.2880%
# Epoch [233/800]	Train Loss :0.0495	 train accuracy :98.2115%	 validation accuracy :99.1211%	 auxiliary class accuracy :55.3595%
# Epoch [234/800]	Train Loss :0.0485	 train accuracy :98.2436%	 validation accuracy :99.2025%	 auxiliary class accuracy :55.3430%
# Epoch [235/800]	Train Loss :0.0515	 train accuracy :98.1111%	 validation accuracy :99.2643%	 auxiliary class accuracy :55.3950%
# Epoch [236/800]	Train Loss :0.0509	 train accuracy :98.1724%	 validation accuracy :99.1797%	 auxiliary class accuracy :55.1340%
# Epoch [237/800]	Train Loss :0.0469	 train accuracy :98.3105%	 validation accuracy :99.2253%	 auxiliary class accuracy :55.3310%
# Epoch [238/800]	Train Loss :0.0457	 train accuracy :98.3133%	 validation accuracy :99.3066%	 auxiliary class accuracy :55.3370%
# Epoch [239/800]	Train Loss :0.0481	 train accuracy :98.3092%	 validation accuracy :99.2155%	 auxiliary class accuracy :55.3215%
# Epoch [240/800]	Train Loss :0.0477	 train accuracy :98.2785%	 validation accuracy :99.1146%	 auxiliary class accuracy :55.5360%
# Epoch [241/800]	Train Loss :0.0459	 train accuracy :98.3636%	 validation accuracy :99.2253%	 auxiliary class accuracy :55.5305%
# Epoch [242/800]	Train Loss :0.0442	 train accuracy :98.4026%	 validation accuracy :99.2415%	 auxiliary class accuracy :55.7280%
# Epoch [243/800]	Train Loss :0.0462	 train accuracy :98.3050%	 validation accuracy :99.3066%	 auxiliary class accuracy :55.9400%
# Epoch [244/800]	Train Loss :0.0487	 train accuracy :98.1766%	 validation accuracy :99.2057%	 auxiliary class accuracy :55.9005%
# Epoch [245/800]	Train Loss :0.0446	 train accuracy :98.3552%	 validation accuracy :99.2253%	 auxiliary class accuracy :56.1450%
# Epoch [246/800]	Train Loss :0.0440	 train accuracy :98.4403%	 validation accuracy :99.3717%	 auxiliary class accuracy :56.1845%
# Epoch [247/800]	Train Loss :0.0437	 train accuracy :98.4598%	 validation accuracy :99.3750%	 auxiliary class accuracy :56.1875%
# Epoch [248/800]	Train Loss :0.0452	 train accuracy :98.3677%	 validation accuracy :99.3327%	 auxiliary class accuracy :56.2090%
# Epoch [249/800]	Train Loss :0.0430	 train accuracy :98.4584%	 validation accuracy :99.4010%	 auxiliary class accuracy :56.0700%
# Epoch [250/800]	Train Loss :0.0435	 train accuracy :98.4221%	 validation accuracy :99.3652%	 auxiliary class accuracy :56.1535%
# Epoch [251/800]	Train Loss :0.0421	 train accuracy :98.4877%	 validation accuracy :99.3945%	 auxiliary class accuracy :56.1195%
# Epoch [252/800]	Train Loss :0.0441	 train accuracy :98.4110%	 validation accuracy :99.3652%	 auxiliary class accuracy :56.0040%
# Epoch [253/800]	Train Loss :0.0453	 train accuracy :98.2994%	 validation accuracy :99.4238%	 auxiliary class accuracy :55.9850%
# Epoch [254/800]	Train Loss :0.0448	 train accuracy :98.3719%	 validation accuracy :99.2708%	 auxiliary class accuracy :55.7505%
# Epoch [255/800]	Train Loss :0.0462	 train accuracy :98.2910%	 validation accuracy :99.3978%	 auxiliary class accuracy :55.9375%
# Epoch [256/800]	Train Loss :0.0430	 train accuracy :98.4473%	 validation accuracy :99.3490%	 auxiliary class accuracy :55.8325%
# Epoch [257/800]	Train Loss :0.0433	 train accuracy :98.4431%	 validation accuracy :99.2220%	 auxiliary class accuracy :56.0675%
# Epoch [258/800]	Train Loss :0.0409	 train accuracy :98.5407%	 validation accuracy :99.3262%	 auxiliary class accuracy :56.1750%
# Epoch [259/800]	Train Loss :0.0425	 train accuracy :98.4989%	 validation accuracy :99.2741%	 auxiliary class accuracy :56.2160%
# Epoch [260/800]	Train Loss :0.0423	 train accuracy :98.5240%	 validation accuracy :99.3685%	 auxiliary class accuracy :56.2645%
# Epoch [261/800]	Train Loss :0.0408	 train accuracy :98.5449%	 validation accuracy :99.4271%	 auxiliary class accuracy :56.3160%
# Epoch [262/800]	Train Loss :0.0412	 train accuracy :98.5421%	 validation accuracy :99.4434%	 auxiliary class accuracy :56.3415%
# Epoch [263/800]	Train Loss :0.0416	 train accuracy :98.5868%	 validation accuracy :99.4206%	 auxiliary class accuracy :56.2980%
# Epoch [264/800]	Train Loss :0.0425	 train accuracy :98.4919%	 validation accuracy :99.4596%	 auxiliary class accuracy :56.3305%
# Epoch [265/800]	Train Loss :0.0416	 train accuracy :98.4654%	 validation accuracy :99.4336%	 auxiliary class accuracy :56.3460%
# Epoch [266/800]	Train Loss :0.0428	 train accuracy :98.4724%	 validation accuracy :99.4759%	 auxiliary class accuracy :56.4445%
# Epoch [267/800]	Train Loss :0.0447	 train accuracy :98.4096%	 validation accuracy :99.4043%	 auxiliary class accuracy :56.1785%
# Epoch [268/800]	Train Loss :0.0479	 train accuracy :98.2478%	 validation accuracy :99.0137%	 auxiliary class accuracy :56.4195%
# Epoch [269/800]	Train Loss :0.0508	 train accuracy :98.2101%	 validation accuracy :99.1927%	 auxiliary class accuracy :56.0400%
# Epoch [270/800]	Train Loss :0.0433	 train accuracy :98.4361%	 validation accuracy :99.4238%	 auxiliary class accuracy :56.2240%
# Epoch [271/800]	Train Loss :0.0418	 train accuracy :98.5338%	 validation accuracy :99.4043%	 auxiliary class accuracy :56.1275%
# Epoch [272/800]	Train Loss :0.0468	 train accuracy :98.3231%	 validation accuracy :99.2741%	 auxiliary class accuracy :55.7710%
# Epoch [273/800]	Train Loss :0.0445	 train accuracy :98.4138%	 validation accuracy :99.1927%	 auxiliary class accuracy :56.0855%
# Epoch [274/800]	Train Loss :0.0403	 train accuracy :98.5505%	 validation accuracy :99.2871%	 auxiliary class accuracy :56.0180%
# Epoch [275/800]	Train Loss :0.0422	 train accuracy :98.4808%	 validation accuracy :99.2057%	 auxiliary class accuracy :56.0385%
# Epoch [276/800]	Train Loss :0.0410	 train accuracy :98.5296%	 validation accuracy :99.3327%	 auxiliary class accuracy :56.2555%
# Epoch [277/800]	Train Loss :0.0401	 train accuracy :98.5993%	 validation accuracy :99.4141%	 auxiliary class accuracy :56.3290%
# Epoch [278/800]	Train Loss :0.0412	 train accuracy :98.5728%	 validation accuracy :99.3262%	 auxiliary class accuracy :56.4070%
# Epoch [279/800]	Train Loss :0.0416	 train accuracy :98.5170%	 validation accuracy :99.4108%	 auxiliary class accuracy :56.6490%
# Epoch [280/800]	Train Loss :0.0381	 train accuracy :98.6454%	 validation accuracy :99.4303%	 auxiliary class accuracy :56.6105%
# Epoch [281/800]	Train Loss :0.0387	 train accuracy :98.6203%	 validation accuracy :99.4108%	 auxiliary class accuracy :56.7265%
# Epoch [282/800]	Train Loss :0.0397	 train accuracy :98.5896%	 validation accuracy :99.4824%	 auxiliary class accuracy :56.8395%
# Epoch [283/800]	Train Loss :0.0386	 train accuracy :98.6258%	 validation accuracy :99.3783%	 auxiliary class accuracy :56.7430%
# Epoch [284/800]	Train Loss :0.0383	 train accuracy :98.6468%	 validation accuracy :99.5280%	 auxiliary class accuracy :56.8180%
# Epoch [285/800]	Train Loss :0.0387	 train accuracy :98.6258%	 validation accuracy :99.5215%	 auxiliary class accuracy :56.8170%
# Epoch [286/800]	Train Loss :0.0391	 train accuracy :98.6300%	 validation accuracy :99.3945%	 auxiliary class accuracy :56.6000%
# Epoch [287/800]	Train Loss :0.0369	 train accuracy :98.7263%	 validation accuracy :99.4564%	 auxiliary class accuracy :56.5730%
# Epoch [288/800]	Train Loss :0.0364	 train accuracy :98.7709%	 validation accuracy :99.4759%	 auxiliary class accuracy :56.3895%
# Epoch [289/800]	Train Loss :0.0383	 train accuracy :98.6370%	 validation accuracy :99.4303%	 auxiliary class accuracy :56.1190%
# Epoch [290/800]	Train Loss :0.0414	 train accuracy :98.5393%	 validation accuracy :99.4694%	 auxiliary class accuracy :56.3885%
# Epoch [291/800]	Train Loss :0.0392	 train accuracy :98.6258%	 validation accuracy :99.4954%	 auxiliary class accuracy :56.0710%
# Epoch [292/800]	Train Loss :0.0355	 train accuracy :98.7458%	 validation accuracy :99.5085%	 auxiliary class accuracy :56.2815%
# Epoch [293/800]	Train Loss :0.0360	 train accuracy :98.7291%	 validation accuracy :99.5443%	 auxiliary class accuracy :56.3665%
# Epoch [294/800]	Train Loss :0.0409	 train accuracy :98.5421%	 validation accuracy :99.2871%	 auxiliary class accuracy :56.1030%
# Epoch [295/800]	Train Loss :0.0412	 train accuracy :98.5156%	 validation accuracy :99.4922%	 auxiliary class accuracy :56.3535%
# Epoch [296/800]	Train Loss :0.0360	 train accuracy :98.7695%	 validation accuracy :99.4173%	 auxiliary class accuracy :56.2415%
# Epoch [297/800]	Train Loss :0.0352	 train accuracy :98.7626%	 validation accuracy :99.5182%	 auxiliary class accuracy :56.4095%
# Epoch [298/800]	Train Loss :0.0364	 train accuracy :98.7305%	 validation accuracy :99.4596%	 auxiliary class accuracy :56.5615%
# Epoch [299/800]	Train Loss :0.0365	 train accuracy :98.7737%	 validation accuracy :99.4954%	 auxiliary class accuracy :56.5095%
# Epoch [300/800]	Train Loss :0.0355	 train accuracy :98.7612%	 validation accuracy :99.5182%	 auxiliary class accuracy :56.7035%
# Epoch [301/800]	Train Loss :0.0355	 train accuracy :98.7416%	 validation accuracy :99.5150%	 auxiliary class accuracy :56.7085%
# Epoch [302/800]	Train Loss :0.0364	 train accuracy :98.6830%	 validation accuracy :99.4336%	 auxiliary class accuracy :56.4575%
# Epoch [303/800]	Train Loss :0.0354	 train accuracy :98.7626%	 validation accuracy :99.5085%	 auxiliary class accuracy :56.6360%
# Epoch [304/800]	Train Loss :0.0339	 train accuracy :98.8295%	 validation accuracy :99.5638%	 auxiliary class accuracy :56.5420%
# Epoch [305/800]	Train Loss :0.0341	 train accuracy :98.8156%	 validation accuracy :99.5638%	 auxiliary class accuracy :56.4965%
# Epoch [306/800]	Train Loss :0.0358	 train accuracy :98.7081%	 validation accuracy :99.6159%	 auxiliary class accuracy :56.6655%
# Epoch [307/800]	Train Loss :0.0349	 train accuracy :98.7193%	 validation accuracy :99.5117%	 auxiliary class accuracy :56.5175%
# Epoch [308/800]	Train Loss :0.0337	 train accuracy :98.8853%	 validation accuracy :99.6257%	 auxiliary class accuracy :56.6440%
# Epoch [309/800]	Train Loss :0.0321	 train accuracy :98.8909%	 validation accuracy :99.5866%	 auxiliary class accuracy :56.5480%
# Epoch [310/800]	Train Loss :0.0333	 train accuracy :98.8170%	 validation accuracy :99.4661%	 auxiliary class accuracy :56.3760%
# Epoch [311/800]	Train Loss :0.0346	 train accuracy :98.7514%	 validation accuracy :99.5736%	 auxiliary class accuracy :56.4255%
# Epoch [312/800]	Train Loss :0.0325	 train accuracy :98.8253%	 validation accuracy :99.5020%	 auxiliary class accuracy :56.1930%
# Epoch [313/800]	Train Loss :0.0327	 train accuracy :98.8797%	 validation accuracy :99.5280%	 auxiliary class accuracy :56.1405%
# Epoch [314/800]	Train Loss :0.0332	 train accuracy :98.8365%	 validation accuracy :99.5150%	 auxiliary class accuracy :56.2495%
# Epoch [315/800]	Train Loss :0.0351	 train accuracy :98.7193%	 validation accuracy :99.4922%	 auxiliary class accuracy :56.1920%
# Epoch [316/800]	Train Loss :0.0344	 train accuracy :98.8016%	 validation accuracy :99.5898%	 auxiliary class accuracy :56.5530%
# Epoch [317/800]	Train Loss :0.0309	 train accuracy :98.9481%	 validation accuracy :99.5768%	 auxiliary class accuracy :56.5190%
# Epoch [318/800]	Train Loss :0.0329	 train accuracy :98.8435%	 validation accuracy :99.5768%	 auxiliary class accuracy :56.6275%
# Epoch [319/800]	Train Loss :0.0331	 train accuracy :98.8449%	 validation accuracy :99.5996%	 auxiliary class accuracy :56.8795%
# Epoch [320/800]	Train Loss :0.0359	 train accuracy :98.7695%	 validation accuracy :99.5020%	 auxiliary class accuracy :56.7450%
# Epoch [321/800]	Train Loss :0.0318	 train accuracy :98.8658%	 validation accuracy :99.6289%	 auxiliary class accuracy :56.7925%
# Epoch [322/800]	Train Loss :0.0297	 train accuracy :98.9900%	 validation accuracy :99.6224%	 auxiliary class accuracy :56.6060%
# Epoch [323/800]	Train Loss :0.0316	 train accuracy :98.8797%	 validation accuracy :99.5833%	 auxiliary class accuracy :56.4795%
# Epoch [324/800]	Train Loss :0.0305	 train accuracy :98.9188%	 validation accuracy :99.6289%	 auxiliary class accuracy :56.5855%
# Epoch [325/800]	Train Loss :0.0308	 train accuracy :98.9509%	 validation accuracy :99.6061%	 auxiliary class accuracy :56.5275%
# Epoch [326/800]	Train Loss :0.0300	 train accuracy :98.9286%	 validation accuracy :99.6354%	 auxiliary class accuracy :56.5600%
# Epoch [327/800]	Train Loss :0.0305	 train accuracy :98.9314%	 validation accuracy :99.6582%	 auxiliary class accuracy :56.5570%
# Epoch [328/800]	Train Loss :0.0301	 train accuracy :98.9872%	 validation accuracy :99.5833%	 auxiliary class accuracy :56.5070%
# Epoch [329/800]	Train Loss :0.0309	 train accuracy :98.8937%	 validation accuracy :99.6712%	 auxiliary class accuracy :56.5830%
# Epoch [330/800]	Train Loss :0.0322	 train accuracy :98.9090%	 validation accuracy :99.5508%	 auxiliary class accuracy :56.5210%
# Epoch [331/800]	Train Loss :0.0309	 train accuracy :98.9118%	 validation accuracy :99.6061%	 auxiliary class accuracy :56.7740%
# Epoch [332/800]	Train Loss :0.0316	 train accuracy :98.9244%	 validation accuracy :99.5671%	 auxiliary class accuracy :56.7140%
# Epoch [333/800]	Train Loss :0.0305	 train accuracy :98.9635%	 validation accuracy :99.6354%	 auxiliary class accuracy :56.8885%
# Epoch [334/800]	Train Loss :0.0307	 train accuracy :98.9146%	 validation accuracy :99.5833%	 auxiliary class accuracy :57.0005%
# Epoch [335/800]	Train Loss :0.0354	 train accuracy :98.7514%	 validation accuracy :99.4792%	 auxiliary class accuracy :56.9685%
# Epoch [336/800]	Train Loss :0.0347	 train accuracy :98.7779%	 validation accuracy :99.5898%	 auxiliary class accuracy :57.4920%
# Epoch [337/800]	Train Loss :0.0333	 train accuracy :98.8281%	 validation accuracy :99.5312%	 auxiliary class accuracy :57.5090%
# Epoch [338/800]	Train Loss :0.0286	 train accuracy :99.0318%	 validation accuracy :99.6094%	 auxiliary class accuracy :57.7010%
# Epoch [339/800]	Train Loss :0.0299	 train accuracy :98.9216%	 validation accuracy :99.6289%	 auxiliary class accuracy :57.7065%
# Epoch [340/800]	Train Loss :0.0306	 train accuracy :98.9648%	 validation accuracy :99.4922%	 auxiliary class accuracy :57.4730%
# Epoch [341/800]	Train Loss :0.0289	 train accuracy :99.0081%	 validation accuracy :99.6224%	 auxiliary class accuracy :57.4305%
# Epoch [342/800]	Train Loss :0.0293	 train accuracy :98.9690%	 validation accuracy :99.6126%	 auxiliary class accuracy :57.2870%
# Epoch [343/800]	Train Loss :0.0324	 train accuracy :98.8477%	 validation accuracy :99.4466%	 auxiliary class accuracy :56.9375%
# Epoch [344/800]	Train Loss :0.0350	 train accuracy :98.7681%	 validation accuracy :99.5573%	 auxiliary class accuracy :57.0610%
# Epoch [345/800]	Train Loss :0.0296	 train accuracy :98.9662%	 validation accuracy :99.5736%	 auxiliary class accuracy :56.7960%
# Epoch [346/800]	Train Loss :0.0294	 train accuracy :99.0109%	 validation accuracy :99.6484%	 auxiliary class accuracy :56.9745%
# Epoch [347/800]	Train Loss :0.0325	 train accuracy :98.8574%	 validation accuracy :99.6452%	 auxiliary class accuracy :57.0785%
# Epoch [348/800]	Train Loss :0.0337	 train accuracy :98.7946%	 validation accuracy :99.4889%	 auxiliary class accuracy :57.0830%
# Epoch [349/800]	Train Loss :0.0279	 train accuracy :98.9886%	 validation accuracy :99.6126%	 auxiliary class accuracy :57.2665%
# Epoch [350/800]	Train Loss :0.0299	 train accuracy :98.9537%	 validation accuracy :99.5410%	 auxiliary class accuracy :57.3815%
# Epoch [351/800]	Train Loss :0.0314	 train accuracy :98.8630%	 validation accuracy :99.4564%	 auxiliary class accuracy :57.3145%
# Epoch [352/800]	Train Loss :0.0297	 train accuracy :98.9537%	 validation accuracy :99.5540%	 auxiliary class accuracy :57.5870%
# Epoch [353/800]	Train Loss :0.0292	 train accuracy :98.9983%	 validation accuracy :99.6061%	 auxiliary class accuracy :57.6670%
# Epoch [354/800]	Train Loss :0.0303	 train accuracy :98.9342%	 validation accuracy :99.5280%	 auxiliary class accuracy :57.5780%
# Epoch [355/800]	Train Loss :0.0278	 train accuracy :99.0541%	 validation accuracy :99.6517%	 auxiliary class accuracy :57.6580%
# Epoch [356/800]	Train Loss :0.0269	 train accuracy :99.0318%	 validation accuracy :99.6354%	 auxiliary class accuracy :57.6740%
# Epoch [357/800]	Train Loss :0.0277	 train accuracy :99.0165%	 validation accuracy :99.6126%	 auxiliary class accuracy :57.7505%
# Epoch [358/800]	Train Loss :0.0286	 train accuracy :98.9802%	 validation accuracy :99.6354%	 auxiliary class accuracy :57.8905%
# Epoch [359/800]	Train Loss :0.0285	 train accuracy :98.9593%	 validation accuracy :99.6452%	 auxiliary class accuracy :57.6615%
# Epoch [360/800]	Train Loss :0.0265	 train accuracy :99.0778%	 validation accuracy :99.6842%	 auxiliary class accuracy :57.6185%
# Epoch [361/800]	Train Loss :0.0267	 train accuracy :99.0737%	 validation accuracy :99.6842%	 auxiliary class accuracy :57.6240%
# Epoch [362/800]	Train Loss :0.0263	 train accuracy :99.1099%	 validation accuracy :99.6582%	 auxiliary class accuracy :57.4895%
# Epoch [363/800]	Train Loss :0.0254	 train accuracy :99.1309%	 validation accuracy :99.6322%	 auxiliary class accuracy :57.4365%
# Epoch [364/800]	Train Loss :0.0267	 train accuracy :99.1057%	 validation accuracy :99.6615%	 auxiliary class accuracy :57.2975%
# Epoch [365/800]	Train Loss :0.0277	 train accuracy :99.0402%	 validation accuracy :99.6875%	 auxiliary class accuracy :57.3060%
# Epoch [366/800]	Train Loss :0.0262	 train accuracy :99.0876%	 validation accuracy :99.6842%	 auxiliary class accuracy :57.3840%
# Epoch [367/800]	Train Loss :0.0254	 train accuracy :99.1532%	 validation accuracy :99.6973%	 auxiliary class accuracy :57.4220%
# Epoch [368/800]	Train Loss :0.0255	 train accuracy :99.1169%	 validation accuracy :99.7038%	 auxiliary class accuracy :57.4280%
# Epoch [369/800]	Train Loss :0.0261	 train accuracy :99.1030%	 validation accuracy :99.7168%	 auxiliary class accuracy :57.4910%
# Epoch [370/800]	Train Loss :0.0248	 train accuracy :99.1127%	 validation accuracy :99.7331%	 auxiliary class accuracy :57.6130%
# Epoch [371/800]	Train Loss :0.0258	 train accuracy :99.1211%	 validation accuracy :99.6484%	 auxiliary class accuracy :57.7600%
# Epoch [372/800]	Train Loss :0.0262	 train accuracy :99.1225%	 validation accuracy :99.7038%	 auxiliary class accuracy :57.9085%
# Epoch [373/800]	Train Loss :0.0257	 train accuracy :99.0946%	 validation accuracy :99.7168%	 auxiliary class accuracy :58.0110%
# ...
# Epoch [677/800]	Train Loss :0.0118	 train accuracy :99.6484%	 validation accuracy :99.8991%	 auxiliary class accuracy :56.0565%
# Epoch [678/800]	Train Loss :0.0139	 train accuracy :99.5201%	 validation accuracy :99.8633%	 auxiliary class accuracy :56.1470%
# Epoch [679/800]	Train Loss :0.0127	 train accuracy :99.5536%	 validation accuracy :99.8828%	 auxiliary class accuracy :56.1410%
# Epoch [680/800]	Train Loss :0.0126	 train accuracy :99.5675%	 validation accuracy :99.8893%	 auxiliary class accuracy :56.1880%
# Epoch [681/800]	Train Loss :0.0132	 train accuracy :99.5633%	 validation accuracy :99.8893%	 auxiliary class accuracy :56.1575%
# Epoch [682/800]	Train Loss :0.0112	 train accuracy :99.6177%	 validation accuracy :99.8958%	 auxiliary class accuracy :56.0405%
# Epoch [683/800]	Train Loss :0.0119	 train accuracy :99.6191%	 validation accuracy :99.8698%	 auxiliary class accuracy :56.0140%
# Epoch [684/800]	Train Loss :0.0111	 train accuracy :99.6359%	 validation accuracy :99.8698%	 auxiliary class accuracy :55.9635%
# Epoch [685/800]	Train Loss :0.0111	 train accuracy :99.6456%	 validation accuracy :99.8633%	 auxiliary class accuracy :55.9335%
# Epoch [686/800]	Train Loss :0.0119	 train accuracy :99.5996%	 validation accuracy :99.8470%	 auxiliary class accuracy :56.0355%
# Epoch [687/800]	Train Loss :0.0129	 train accuracy :99.6024%	 validation accuracy :99.8893%	 auxiliary class accuracy :56.0235%
# Epoch [688/800]	Train Loss :0.0117	 train accuracy :99.6052%	 validation accuracy :99.9023%	 auxiliary class accuracy :55.9800%
# Epoch [689/800]	Train Loss :0.0113	 train accuracy :99.6205%	 validation accuracy :99.9056%	 auxiliary class accuracy :55.9200%
# Epoch [690/800]	Train Loss :0.0113	 train accuracy :99.6289%	 validation accuracy :99.9219%	 auxiliary class accuracy :55.8825%
# Epoch [691/800]	Train Loss :0.0105	 train accuracy :99.6680%	 validation accuracy :99.8926%	 auxiliary class accuracy :55.8160%
# Epoch [692/800]	Train Loss :0.0114	 train accuracy :99.6219%	 validation accuracy :99.8796%	 auxiliary class accuracy :56.0505%
# Epoch [693/800]	Train Loss :0.0109	 train accuracy :99.6429%	 validation accuracy :99.8893%	 auxiliary class accuracy :56.0840%
# Epoch [694/800]	Train Loss :0.0106	 train accuracy :99.6331%	 validation accuracy :99.8893%	 auxiliary class accuracy :56.0950%
# Epoch [695/800]	Train Loss :0.0101	 train accuracy :99.6512%	 validation accuracy :99.8926%	 auxiliary class accuracy :56.1230%
# Epoch [696/800]	Train Loss :0.0112	 train accuracy :99.6359%	 validation accuracy :99.9121%	 auxiliary class accuracy :56.1315%
# Epoch [697/800]	Train Loss :0.0102	 train accuracy :99.6359%	 validation accuracy :99.9316%	 auxiliary class accuracy :56.2005%
# Epoch [698/800]	Train Loss :0.0102	 train accuracy :99.6610%	 validation accuracy :99.9219%	 auxiliary class accuracy :56.2110%
# Epoch [699/800]	Train Loss :0.0124	 train accuracy :99.6345%	 validation accuracy :99.9154%	 auxiliary class accuracy :56.2045%
# Epoch [700/800]	Train Loss :0.0107	 train accuracy :99.6345%	 validation accuracy :99.9056%	 auxiliary class accuracy :56.1480%
# Epoch [701/800]	Train Loss :0.0106	 train accuracy :99.6652%	 validation accuracy :99.9089%	 auxiliary class accuracy :56.1425%
# Epoch [702/800]	Train Loss :0.0097	 train accuracy :99.6610%	 validation accuracy :99.9089%	 auxiliary class accuracy :56.1070%
# Epoch [703/800]	Train Loss :0.0101	 train accuracy :99.6429%	 validation accuracy :99.9089%	 auxiliary class accuracy :56.0970%
# Epoch [704/800]	Train Loss :0.0102	 train accuracy :99.6568%	 validation accuracy :99.9251%	 auxiliary class accuracy :56.0520%
# Epoch [705/800]	Train Loss :0.0100	 train accuracy :99.6554%	 validation accuracy :99.9154%	 auxiliary class accuracy :56.0045%
# Epoch [706/800]	Train Loss :0.0100	 train accuracy :99.6540%	 validation accuracy :99.9316%	 auxiliary class accuracy :55.9870%
# Epoch [707/800]	Train Loss :0.0107	 train accuracy :99.6387%	 validation accuracy :99.9284%	 auxiliary class accuracy :55.9810%
# Epoch [708/800]	Train Loss :0.0107	 train accuracy :99.6652%	 validation accuracy :99.9284%	 auxiliary class accuracy :55.9945%
# Epoch [709/800]	Train Loss :0.0102	 train accuracy :99.6819%	 validation accuracy :99.9056%	 auxiliary class accuracy :55.9425%
# Epoch [710/800]	Train Loss :0.0106	 train accuracy :99.6526%	 validation accuracy :99.9121%	 auxiliary class accuracy :55.8985%
# Epoch [711/800]	Train Loss :0.0090	 train accuracy :99.7029%	 validation accuracy :99.9023%	 auxiliary class accuracy :55.9125%
# Epoch [712/800]	Train Loss :0.0098	 train accuracy :99.6610%	 validation accuracy :99.9056%	 auxiliary class accuracy :55.9130%
# Epoch [713/800]	Train Loss :0.0103	 train accuracy :99.6415%	 validation accuracy :99.9186%	 auxiliary class accuracy :55.9110%
# Epoch [714/800]	Train Loss :0.0103	 train accuracy :99.6680%	 validation accuracy :99.8958%	 auxiliary class accuracy :55.9180%
# Epoch [715/800]	Train Loss :0.0106	 train accuracy :99.6749%	 validation accuracy :99.9186%	 auxiliary class accuracy :55.9325%
# Epoch [716/800]	Train Loss :0.0108	 train accuracy :99.6359%	 validation accuracy :99.9089%	 auxiliary class accuracy :55.9160%
# Epoch [717/800]	Train Loss :0.0109	 train accuracy :99.6219%	 validation accuracy :99.9121%	 auxiliary class accuracy :56.0095%
# Epoch [718/800]	Train Loss :0.0105	 train accuracy :99.6205%	 validation accuracy :99.9251%	 auxiliary class accuracy :56.0760%
# Epoch [719/800]	Train Loss :0.0112	 train accuracy :99.6359%	 validation accuracy :99.8828%	 auxiliary class accuracy :56.0665%
# Epoch [720/800]	Train Loss :0.0105	 train accuracy :99.6568%	 validation accuracy :99.9414%	 auxiliary class accuracy :56.0975%
# Epoch [721/800]	Train Loss :0.0102	 train accuracy :99.6610%	 validation accuracy :99.9479%	 auxiliary class accuracy :56.0770%
# Epoch [722/800]	Train Loss :0.0094	 train accuracy :99.6722%	 validation accuracy :99.9381%	 auxiliary class accuracy :56.0565%
# Epoch [723/800]	Train Loss :0.0100	 train accuracy :99.6861%	 validation accuracy :99.9186%	 auxiliary class accuracy :56.0285%
# Epoch [724/800]	Train Loss :0.0094	 train accuracy :99.6959%	 validation accuracy :99.9414%	 auxiliary class accuracy :55.9940%
# Epoch [725/800]	Train Loss :0.0100	 train accuracy :99.6652%	 validation accuracy :99.9447%	 auxiliary class accuracy :55.9345%
# Epoch [726/800]	Train Loss :0.0098	 train accuracy :99.6777%	 validation accuracy :99.9414%	 auxiliary class accuracy :55.8835%
# Epoch [727/800]	Train Loss :0.0100	 train accuracy :99.6624%	 validation accuracy :99.9284%	 auxiliary class accuracy :55.8925%
# Epoch [728/800]	Train Loss :0.0104	 train accuracy :99.6582%	 validation accuracy :99.8861%	 auxiliary class accuracy :55.9335%
# Epoch [729/800]	Train Loss :0.0100	 train accuracy :99.6861%	 validation accuracy :99.8633%	 auxiliary class accuracy :55.9345%
# Epoch [730/800]	Train Loss :0.0090	 train accuracy :99.7224%	 validation accuracy :99.8763%	 auxiliary class accuracy :55.8610%
# Epoch [731/800]	Train Loss :0.0108	 train accuracy :99.6247%	 validation accuracy :99.8665%	 auxiliary class accuracy :55.8500%
# Epoch [732/800]	Train Loss :0.0117	 train accuracy :99.6331%	 validation accuracy :99.8665%	 auxiliary class accuracy :55.8490%
# Epoch [733/800]	Train Loss :0.0116	 train accuracy :99.6345%	 validation accuracy :99.9316%	 auxiliary class accuracy :55.7860%
# Epoch [734/800]	Train Loss :0.0107	 train accuracy :99.6470%	 validation accuracy :99.9154%	 auxiliary class accuracy :55.7135%
# Epoch [735/800]	Train Loss :0.0107	 train accuracy :99.6456%	 validation accuracy :99.9089%	 auxiliary class accuracy :55.7410%
# Epoch [736/800]	Train Loss :0.0102	 train accuracy :99.6568%	 validation accuracy :99.8893%	 auxiliary class accuracy :55.8035%
# Epoch [737/800]	Train Loss :0.0107	 train accuracy :99.6219%	 validation accuracy :99.8665%	 auxiliary class accuracy :55.8685%
# Epoch [738/800]	Train Loss :0.0097	 train accuracy :99.6917%	 validation accuracy :99.9251%	 auxiliary class accuracy :55.8465%
# Epoch [739/800]	Train Loss :0.0101	 train accuracy :99.6903%	 validation accuracy :99.9251%	 auxiliary class accuracy :55.8310%
# Epoch [740/800]	Train Loss :0.0115	 train accuracy :99.6219%	 validation accuracy :99.9251%	 auxiliary class accuracy :55.8145%
# Epoch [741/800]	Train Loss :0.0086	 train accuracy :99.7070%	 validation accuracy :99.9219%	 auxiliary class accuracy :55.8015%
# Epoch [742/800]	Train Loss :0.0100	 train accuracy :99.6749%	 validation accuracy :99.9316%	 auxiliary class accuracy :55.8715%
# Epoch [743/800]	Train Loss :0.0093	 train accuracy :99.7015%	 validation accuracy :99.9186%	 auxiliary class accuracy :55.8110%
# Epoch [744/800]	Train Loss :0.0091	 train accuracy :99.7029%	 validation accuracy :99.9154%	 auxiliary class accuracy :55.7625%
# Epoch [745/800]	Train Loss :0.0091	 train accuracy :99.6917%	 validation accuracy :99.9186%	 auxiliary class accuracy :55.6900%
# Epoch [746/800]	Train Loss :0.0112	 train accuracy :99.6303%	 validation accuracy :99.9284%	 auxiliary class accuracy :55.7135%
# Epoch [747/800]	Train Loss :0.0098	 train accuracy :99.6610%	 validation accuracy :99.9414%	 auxiliary class accuracy :55.6995%
# Epoch [748/800]	Train Loss :0.0091	 train accuracy :99.6736%	 validation accuracy :99.9316%	 auxiliary class accuracy :55.7375%
# Epoch [749/800]	Train Loss :0.0093	 train accuracy :99.6903%	 validation accuracy :99.9121%	 auxiliary class accuracy :55.7485%
# Epoch [750/800]	Train Loss :0.0097	 train accuracy :99.6847%	 validation accuracy :99.8763%	 auxiliary class accuracy :55.7870%
# Epoch [751/800]	Train Loss :0.0095	 train accuracy :99.6805%	 validation accuracy :99.8828%	 auxiliary class accuracy :55.8485%
# Epoch [752/800]	Train Loss :0.0097	 train accuracy :99.6763%	 validation accuracy :99.9089%	 auxiliary class accuracy :55.9635%
# Epoch [753/800]	Train Loss :0.0089	 train accuracy :99.7029%	 validation accuracy :99.9186%	 auxiliary class accuracy :55.9755%
# Epoch [754/800]	Train Loss :0.0087	 train accuracy :99.7112%	 validation accuracy :99.9219%	 auxiliary class accuracy :56.0620%
# Epoch [755/800]	Train Loss :0.0098	 train accuracy :99.6610%	 validation accuracy :99.9316%	 auxiliary class accuracy :56.1740%
# Epoch [756/800]	Train Loss :0.0109	 train accuracy :99.6275%	 validation accuracy :99.8926%	 auxiliary class accuracy :56.2725%
# Epoch [757/800]	Train Loss :0.0125	 train accuracy :99.5661%	 validation accuracy :99.8698%	 auxiliary class accuracy :56.3010%
# Epoch [758/800]	Train Loss :0.0096	 train accuracy :99.7001%	 validation accuracy :99.9284%	 auxiliary class accuracy :56.2775%
# Epoch [759/800]	Train Loss :0.0115	 train accuracy :99.6150%	 validation accuracy :99.9251%	 auxiliary class accuracy :56.1935%
# Epoch [760/800]	Train Loss :0.0118	 train accuracy :99.6303%	 validation accuracy :99.9121%	 auxiliary class accuracy :56.0930%
# Epoch [761/800]	Train Loss :0.0101	 train accuracy :99.6470%	 validation accuracy :99.8893%	 auxiliary class accuracy :56.0165%
# Epoch [762/800]	Train Loss :0.0096	 train accuracy :99.6498%	 validation accuracy :99.8405%	 auxiliary class accuracy :55.9845%
# Epoch [763/800]	Train Loss :0.0105	 train accuracy :99.6554%	 validation accuracy :99.9186%	 auxiliary class accuracy :56.0380%
# Epoch [764/800]	Train Loss :0.0109	 train accuracy :99.6415%	 validation accuracy :99.9089%	 auxiliary class accuracy :56.0420%
# Epoch [765/800]	Train Loss :0.0097	 train accuracy :99.6945%	 validation accuracy :99.8926%	 auxiliary class accuracy :56.0040%
# Epoch [766/800]	Train Loss :0.0097	 train accuracy :99.7182%	 validation accuracy :99.9381%	 auxiliary class accuracy :55.9070%
# Epoch [767/800]	Train Loss :0.0088	 train accuracy :99.7084%	 validation accuracy :99.9219%	 auxiliary class accuracy :55.7630%
# Epoch [768/800]	Train Loss :0.0086	 train accuracy :99.7196%	 validation accuracy :99.9056%	 auxiliary class accuracy :55.6260%
# Epoch [769/800]	Train Loss :0.0112	 train accuracy :99.6331%	 validation accuracy :99.9089%	 auxiliary class accuracy :55.5690%
# Epoch [770/800]	Train Loss :0.0091	 train accuracy :99.6875%	 validation accuracy :99.9251%	 auxiliary class accuracy :55.4620%
# Epoch [771/800]	Train Loss :0.0097	 train accuracy :99.6861%	 validation accuracy :99.9316%	 auxiliary class accuracy :55.4385%
# Epoch [772/800]	Train Loss :0.0095	 train accuracy :99.6959%	 validation accuracy :99.9219%	 auxiliary class accuracy :55.4325%
# Epoch [773/800]	Train Loss :0.0096	 train accuracy :99.6833%	 validation accuracy :99.8991%	 auxiliary class accuracy :55.3470%
# Epoch [774/800]	Train Loss :0.0080	 train accuracy :99.7280%	 validation accuracy :99.9219%	 auxiliary class accuracy :55.3645%
# Epoch [775/800]	Train Loss :0.0096	 train accuracy :99.6470%	 validation accuracy :99.9219%	 auxiliary class accuracy :55.3050%
# Epoch [776/800]	Train Loss :0.0088	 train accuracy :99.7098%	 validation accuracy :99.9512%	 auxiliary class accuracy :55.2695%
# Epoch [777/800]	Train Loss :0.0087	 train accuracy :99.7224%	 validation accuracy :99.9349%	 auxiliary class accuracy :55.2355%
# Epoch [778/800]	Train Loss :0.0093	 train accuracy :99.6973%	 validation accuracy :99.9251%	 auxiliary class accuracy :55.2555%
# Epoch [779/800]	Train Loss :0.0085	 train accuracy :99.7001%	 validation accuracy :99.9479%	 auxiliary class accuracy :55.2900%
# Epoch [780/800]	Train Loss :0.0079	 train accuracy :99.7280%	 validation accuracy :99.9512%	 auxiliary class accuracy :55.3600%
# Epoch [781/800]	Train Loss :0.0089	 train accuracy :99.7029%	 validation accuracy :99.9577%	 auxiliary class accuracy :55.4195%
# Epoch [782/800]	Train Loss :0.0085	 train accuracy :99.7252%	 validation accuracy :99.9512%	 auxiliary class accuracy :55.5365%
# Epoch [783/800]	Train Loss :0.0087	 train accuracy :99.6791%	 validation accuracy :99.9284%	 auxiliary class accuracy :55.5850%
# Epoch [784/800]	Train Loss :0.0100	 train accuracy :99.6666%	 validation accuracy :99.8307%	 auxiliary class accuracy :55.6520%
# Epoch [785/800]	Train Loss :0.0104	 train accuracy :99.6749%	 validation accuracy :99.8926%	 auxiliary class accuracy :55.6605%
# Epoch [786/800]	Train Loss :0.0084	 train accuracy :99.7238%	 validation accuracy :99.9186%	 auxiliary class accuracy :55.6600%
# Epoch [787/800]	Train Loss :0.0099	 train accuracy :99.6791%	 validation accuracy :99.9219%	 auxiliary class accuracy :55.6045%
# Epoch [788/800]	Train Loss :0.0103	 train accuracy :99.6540%	 validation accuracy :99.9089%	 auxiliary class accuracy :55.6040%
# Epoch [789/800]	Train Loss :0.0082	 train accuracy :99.7266%	 validation accuracy :99.9186%	 auxiliary class accuracy :55.5375%
# Epoch [790/800]	Train Loss :0.0094	 train accuracy :99.6763%	 validation accuracy :99.9023%	 auxiliary class accuracy :55.5570%
# Epoch [791/800]	Train Loss :0.0099	 train accuracy :99.6749%	 validation accuracy :99.8698%	 auxiliary class accuracy :55.6330%
# Epoch [792/800]	Train Loss :0.0092	 train accuracy :99.6903%	 validation accuracy :99.9089%	 auxiliary class accuracy :55.6755%
# Epoch [793/800]	Train Loss :0.0092	 train accuracy :99.7084%	 validation accuracy :99.8698%	 auxiliary class accuracy :55.7430%
# Epoch [794/800]	Train Loss :0.0102	 train accuracy :99.6749%	 validation accuracy :99.9219%	 auxiliary class accuracy :55.8325%
# Epoch [795/800]	Train Loss :0.0084	 train accuracy :99.7029%	 validation accuracy :99.9479%	 auxiliary class accuracy :55.8145%
# Epoch [796/800]	Train Loss :0.0090	 train accuracy :99.7210%	 validation accuracy :99.9381%	 auxiliary class accuracy :55.8090%
# Epoch [797/800]	Train Loss :0.0085	 train accuracy :99.7308%	 validation accuracy :99.9512%	 auxiliary class accuracy :55.8440%
# Epoch [798/800]	Train Loss :0.0081	 train accuracy :99.7475%	 validation accuracy :99.9381%	 auxiliary class accuracy :55.7320%
# Epoch [799/800]	Train Loss :0.0078	 train accuracy :99.7489%	 validation accuracy :99.9251%	 auxiliary class accuracy :55.6040%
# Epoch [800/800]	Train Loss :0.0080	 train accuracy :99.7419%	 validation accuracy :99.9349%	 auxiliary class accuracy :55.5615%
#
# Training Completed

# %% [markdown]
# # Analysis

# %%
plt.plot(range(num_epochs+1)[1:], obj_vals) # plot loss function

# %%
# plot accuracies
plt.plot(range(num_epochs+1)[1:], train_accuracies, label="Synthetic train")
plt.plot(range(num_epochs+1)[1:], valid_accuracies, label="Synthetic test")
plt.plot(range(num_epochs+1)[1:], aux_accuracies, label="GEANT test", alpha=0.5)
max_valid_accuracy = max(valid_accuracies)
max_valid_index = valid_accuracies.index(max_valid_accuracy)+1
max_aux_accuracy = max(aux_accuracies)
max_aux_index = aux_accuracies.index(max_aux_accuracy)+1
plt.axvline(x=(max_valid_index), color='orange', linestyle='--', label="Synthetic max test\naccuracy {:.4f}".format(max_valid_accuracy))
plt.axvline(x=(max_aux_index), color='green', linestyle=':', label="GEANT max test\naccuracy {:.4f}".format(max_aux_accuracy))
plt.xlabel('Epochs')
plt.ylabel('Accuracies')
plt.legend(loc="lower right")
plt.title("Synthetic Train (GEANT and Synthetic Test) ($\gamma$ AND $e^{+}$)")
# Out:
# Text(0.5, 1.0, 'Synthetic Train (GEANT and Synthetic Test) ($\\gamma$ AND $e^{+}$)')

# %%
print('The validation accuracy reaches maximum at {:.2f}% at epoch {}, with the test accuracy at {:.2f}%\t'.format(float(max_valid_accuracy)*100, max_valid_index,float(aux_accuracies[max_valid_index-1])*100))
# Out:
# The validation accuracy reaches maximum at 99.96% at epoch 781, with the test accuracy at 55.42%
